# %%
import csv
import collections
import os
import pickle

# %%
hor_results = collections.defaultdict(lambda: collections.defaultdict(collections.Counter))
precinct_results = collections.defaultdict(
        lambda: collections.defaultdict(
            collections.Counter
        )
)
fieldnames = ["county_abbr", "county_name", "unk", "election_date", "election", "precinct_number", 
              "polling_location", "unk", "unk", "unk", "unk", "ballot_measure", "district", "unk", 
              "candidate", "party", "unk", "unk", "vote_count"]

directory = "data"
for subdir, dirs, files in os.walk(directory):
    for f in files:
        if "2012" not in f:
            try:
                if f.endswith('.txt'):
                    with open(os.path.join(subdir, f), encoding = "ISO-8859-1") as csvfile:
                        dr = csv.DictReader(csvfile, fieldnames=fieldnames, delimiter='\t')
                        for row in dr:
                            if row["ballot_measure"] == "U.S. Representative" or row["ballot_measure"] == "Representative in Congress":
                                hor_results[row["election"]][row["district"]][row["party"]] += int(row["vote_count"])
                                precinct_number = int(float(row["precinct_number"]))

                                # The dataset subdivides precincts for some elections but not for others.
                                # To get precinct data across all elections, we unify the subdivisions.
                                precinct_results[
                                    row["county_abbr"] + str(precinct_number)][
                                    row["election"]][
                                    row["party"]] += int(row["vote_count"])
                                precinct_results[
                                    row["county_abbr"] + str(precinct_number)][
                                    row["election"]]["district"] = row["district"]
            except Exception as e:
                print("Corrupt file: {} - {}".format(f, e))
# Out:
# Corrupt file: BAK_PctResults20141104.txt - could not convert string to float: '1A'
# Corrupt file: BRO_PctResults20141104.txt - could not convert string to float: 'A001'
# Corrupt file: GIL_PctResults20141104.txt - could not convert string to float: '1A'
# Corrupt file: UNI_PctResults20141104.txt - could not convert string to float: '1A & 1B'
# Corrupt file: BAK_PctResults20161108.txt - could not convert string to float: '1A'
# Corrupt file: BRO_PctResults20161108.txt - could not convert string to float: 'A001'
# Corrupt file: GIL_PctResults20161108.txt - could not convert string to float: '1A'
# Corrupt file: UNI_PctResults20161108.txt - could not convert string to float: '1A & 1B'

# %%
two_years_results = {key: results for key, results in precinct_results.items() if len(results) == 2}

# %%
to_del = set()
# We remove small precincts from the analysis
for key, value in two_years_results.items():
    for election, results in value.items():
        if results["DEM"] <= 5 and results["REP"] <= 5:
            to_del.add(key)

for key in to_del:
    del two_years_results[key]

# %%
for key, value in two_years_results.items():
    for election, results in value.items():
        if "2012 General Election" not in election:
            two_years_results[key][election]["total"] = results["DEM"] + results["REP"]
            two_years_results[key][election]["ratio"] = results["DEM"] / (results["DEM"] + results["REP"])
    total_dem_votes = sum([int(votes["DEM"]) for votes in value.values()])
    total_rep_votes = sum([int(votes["REP"]) for votes in value.values()])
    two_years_results[key]["ratio"] = total_dem_votes / (total_dem_votes + total_rep_votes)
    total_2014_votes = value["2014 General Election"]["total"]
    total_2016_votes = value["2016 General Election"]["total"]
    voter_increase = max(0, total_2016_votes - total_2014_votes)
    two_years_results[key]["voter_increase"] = voter_increase
    two_years_results[key]["midterm_voter_percentage"] = float(total_2014_votes)/total_2016_votes
    two_years_results[key]["dem_missing_voters"] = two_years_results[key]["ratio"] * voter_increase
    two_years_results[key]["rep_missing_voters"] = (1 - two_years_results[key]["ratio"]) * voter_increase
    two_years_results[key]["dem_delta"] = two_years_results[key]["dem_missing_voters"] - two_years_results[key]["rep_missing_voters"]
    two_years_results[key]["new_d_voter_odds"] = two_years_results[key]["dem_delta"]/value["2016 General Election"]["total"]

# %%
competitive_districts = [6, 15, 16, 18, 25, 26, 27]
comp_dist_names = [" District {}".format(dist) for dist in competitive_districts]
districts_dict = collections.defaultdict(dict)
for district_name in comp_dist_names:
    district_results = {key: value for key, value in two_years_results.items() if value["2016 General Election"]["district"] == district_name}
    districts_dict[district_name] = sorted(district_results.items(), key=lambda x: x[1]["dem_delta"]/x[1]["2016 General Election"]["total"], reverse=True)

# %%
for district, results in districts_dict.items():
    print(district)
    print(results[0])
    print()
# Out:
#  District 6
# ('VOL620', defaultdict(<class 'collections.Counter'>, {'2014 General Election': Counter({'REP': 6, 'district': ' District 6', 'DEM': 383, ' ': 10, 'total': 389, 'ratio': 0.9845758354755784}), '2016 General Election': Counter({'REP': 55, 'district': ' District 6', 'DEM': 1343, ' ': 57, 'total': 1398, 'ratio': 0.9606580829756796}), 'ratio': 0.965864577504197, 'voter_increase': 1009, 'midterm_voter_percentage': 0.2782546494992847, 'dem_missing_voters': 974.5573587017348, 'rep_missing_voters': 34.442641298265265, 'dem_delta': 940.1147174034695}))
#
#  District 15
# ('HIL753', defaultdict(<class 'collections.Counter'>, {'2014 General Election': Counter({'REP': 372, 'district': ' District 15', 'DEM': 960, ' ': 64, 'total': 1332, 'ratio': 0.7207207207207207}), '2016 General Election': Counter({'REP': 691, 'district': ' District 15', 'DEM': 1522, ' ': 149, 'total': 2213, 'ratio': 0.6877541798463624}), 'ratio': 0.7001410437235543, 'voter_increase': 881, 'midterm_voter_percentage': 0.6018978761861726, 'dem_missing_voters': 616.8242595204514, 'rep_missing_voters': 264.1757404795486, 'dem_delta': 352.6485190409028}))
#
#  District 16
# ('SAR115', defaultdict(<class 'collections.Counter'>, {'2014 General Election': Counter({'REP': 397, 'district': ' District 16', 'DEM': 1663, ' ': 64, 'total': 2060, 'ratio': 0.8072815533980583}), '2016 General Election': Counter({'REP': 714, 'district': ' District 16', 'DEM': 2910, ' ': 192, 'total': 3624, 'ratio': 0.8029801324503312}), 'ratio': 0.8045390570021111, 'voter_increase': 1564, 'midterm_voter_percentage': 0.5684326710816777, 'dem_missing_voters': 1258.2990851513018, 'rep_missing_voters': 305.7009148486982, 'dem_delta': 952.5981703026036}))
#
#  District 18
# ('STL17', defaultdict(<class 'collections.Counter'>, {'2014 General Election': Counter({'REP': 21, 'district': ' District 18', 'DEM': 1257, ' ': 18, 'total': 1278, 'ratio': 0.9835680751173709}), '2016 General Election': Counter({'REP': 47, 'district': ' District 18', 'DEM': 1795, 'NPA': 58, ' ': 41, 'total': 1842, 'ratio': 0.9744842562432139}), 'ratio': 0.9782051282051282, 'voter_increase': 564, 'midterm_voter_percentage': 0.6938110749185668, 'dem_missing_voters': 551.7076923076922, 'rep_missing_voters': 12.29230769230771, 'dem_delta': 539.4153846153845}))
#
#  District 25
# ('HEN1', defaultdict(<class 'collections.Counter'>, {'2014 General Election': Counter({'REP': 220, 'district': ' District 20', 'DEM': 973, ' ': 32, 'total': 1193, 'ratio': 0.815590947191953}), '2016 General Election': Counter({'REP': 496, 'district': ' District 25', 'DEM': 1526, ' ': 113, 'total': 2022, 'ratio': 0.7546983184965381}), 'ratio': 0.7772939346811819, 'voter_increase': 829, 'midterm_voter_percentage': 0.5900098911968348, 'dem_missing_voters': 644.3766718506998, 'rep_missing_voters': 184.6233281493002, 'dem_delta': 459.7533437013997}))
#
#  District 26
# ('DAD813', defaultdict(<class 'collections.Counter'>, {'2014 General Election': Counter({'REP': 252, 'district': ' District 26', 'DEM': 1410, ' ': 66, 'total': 1662, 'ratio': 0.8483754512635379}), '2016 General Election': Counter({'REP': 659, 'district': ' District 26', 'DEM': 1920, 'NPA': 141, ' ': 116, 'total': 2579, 'ratio': 0.7444746025591314}), 'ratio': 0.7851921716576279, 'voter_increase': 917, 'midterm_voter_percentage': 0.6444358278402481, 'dem_missing_voters': 720.0212214100447, 'rep_missing_voters': 196.97877858995523, 'dem_delta': 523.0424428200895}))
#
#  District 27
# ('DAD41', defaultdict(<class 'collections.Counter'>, {'2014 General Election': Counter({'REP': 317, 'district': ' District 23', 'DEM': 915, ' ': 79, 'total': 1232, 'ratio': 0.7426948051948052}), '2016 General Election': Counter({'REP': 819, 'district': ' District 27', 'DEM': 1591, ' ': 165, 'total': 2410, 'ratio': 0.6601659751037344}), 'ratio': 0.6880834706205382, 'voter_increase': 1178, 'midterm_voter_percentage': 0.5112033195020746, 'dem_missing_voters': 810.562328390994, 'rep_missing_voters': 367.437671609006, 'dem_delta': 443.12465678198805}))

# %%
fieldnames = [
    "Precinct", 
    "DEM votes 2014", 
    "REP votes 2014", 
    "DEM votes 2016", 
    "REP votes 2016", 
    "DEM vote share", 
    "midterm voter percentage", 
    "DEM missing voters", 
    "REP missing voters", 
    "DEM potential gain"
]
def dict_writer_formatter(pickups_list):
    output_rows = []
    for precinct_data in pickups_list:
        results = precinct_data[1]
        row_dict = {}
        row_dict["Precinct"] = precinct_data[0]
        row_dict["DEM votes 2014"] = results["2014 General Election"]["DEM"]
        row_dict["REP votes 2014"] = results["2014 General Election"]["REP"]
        row_dict["DEM votes 2016"] = results["2016 General Election"]["DEM"]
        row_dict["REP votes 2016"] = results["2016 General Election"]["REP"]
        row_dict["DEM vote share"] = results["ratio"]
        row_dict["midterm voter percentage"] = results["midterm_voter_percentage"]
        row_dict["DEM missing voters"] = results["dem_missing_voters"]
        row_dict["REP missing voters"] = results["rep_missing_voters"]
        row_dict["DEM potential gain"] = results["dem_delta"]
        output_rows.append(row_dict)
    return output_rows

# %%
dict_writer_formatter(districts_dict[" District 6"])
# Out:
# [{'Precinct': 'VOL620',
#   'DEM votes 2014': 383,
#   'REP votes 2014': 6,
#   'DEM votes 2016': 1343,
#   'REP votes 2016': 55,
#   'DEM vote share': 0.965864577504197,
#   'midterm voter percentage': 0.2782546494992847,
#   'DEM missing voters': 974.5573587017348,
#   'REP missing voters': 34.442641298265265,
#   'DEM potential gain': 940.1147174034695},
#  {'Precinct': 'VOL614',
#   'DEM votes 2014': 1025,
#   'REP votes 2014': 236,
#   'DEM votes 2016': 1881,
#   'REP votes 2016': 496,
#   'DEM vote share': 0.7987905442550852,
#   'midterm voter percentage': 0.5305006310475389,
#   'DEM missing voters': 891.450247388675,
#   'REP missing voters': 224.5497526113249,
#   'DEM potential gain': 666.9004947773501},
#  {'Precinct': 'VOL628',
#   'DEM votes 2014': 1080,
#   'REP votes 2014': 231,
#   'DEM votes 2016': 1813,
#   'REP votes 2016': 447,
#   'DEM vote share': 0.8101372164659759,
#   'midterm voter percentage': 0.5800884955752212,
#   'DEM missing voters': 768.8202184262111,
#   'REP missing voters': 180.17978157378886,
#   'DEM potential gain': 588.6404368524222},
#  {'Precinct': 'VOL603',
#   'DEM votes 2014': 1079,
#   'REP votes 2014': 283,
#   'DEM votes 2016': 1711,
#   'REP votes 2016': 520,
#   'DEM vote share': 0.77650988032285,
#   'midterm voter percentage': 0.6104885701479157,
#   'DEM missing voters': 674.7870860005567,
#   'REP missing voters': 194.2129139994434,
#   'DEM potential gain': 480.57417200111325},
#  {'Precinct': 'VOL619',
#   'DEM votes 2014': 655,
#   'REP votes 2014': 101,
#   'DEM votes 2016': 1089,
#   'REP votes 2016': 217,
#   'DEM vote share': 0.8457807953443259,
#   'midterm voter percentage': 0.5788667687595712,
#   'DEM missing voters': 465.1794374393793,
#   'REP missing voters': 84.82056256062074,
#   'DEM potential gain': 380.35887487875857},
#  {'Precinct': 'VOL621',
#   'DEM votes 2014': 641,
#   'REP votes 2014': 87,
#   'DEM votes 2016': 991,
#   'REP votes 2016': 131,
#   'DEM vote share': 0.8821621621621621,
#   'midterm voter percentage': 0.6488413547237076,
#   'DEM missing voters': 347.5718918918919,
#   'REP missing voters': 46.42810810810811,
#   'DEM potential gain': 301.14378378378376},
#  {'Precinct': 'VOL217',
#   'DEM votes 2014': 861,
#   'REP votes 2014': 422,
#   'DEM votes 2016': 1364,
#   'REP votes 2016': 599,
#   'DEM vote share': 0.6854590264941467,
#   'midterm voter percentage': 0.6535914416709119,
#   'DEM missing voters': 466.11213801601974,
#   'REP missing voters': 213.88786198398026,
#   'DEM potential gain': 252.22427603203948},
#  {'Precinct': 'VOL633',
#   'DEM votes 2014': 985,
#   'REP votes 2014': 559,
#   'DEM votes 2016': 1552,
#   'REP votes 2016': 1004,
#   'DEM vote share': 0.618780487804878,
#   'midterm voter percentage': 0.6040688575899843,
#   'DEM missing voters': 626.2058536585366,
#   'REP missing voters': 385.79414634146343,
#   'DEM potential gain': 240.4117073170732},
#  {'Precinct': 'LAK57',
#   'DEM votes 2014': 334,
#   'REP votes 2014': 76,
#   'DEM votes 2016': 516,
#   'REP votes 2016': 116,
#   'DEM vote share': 0.8157389635316699,
#   'midterm voter percentage': 0.6487341772151899,
#   'DEM missing voters': 181.0940499040307,
#   'REP missing voters': 40.90595009596929,
#   'DEM potential gain': 140.1880998080614},
#  {'Precinct': 'VOL220',
#   'DEM votes 2014': 212,
#   'REP votes 2014': 12,
#   'DEM votes 2016': 320,
#   'REP votes 2016': 25,
#   'DEM vote share': 0.9349736379613357,
#   'midterm voter percentage': 0.6492753623188405,
#   'DEM missing voters': 113.13181019332163,
#   'REP missing voters': 7.86818980667838,
#   'DEM potential gain': 105.26362038664325},
#  {'Precinct': 'VOL216',
#   'DEM votes 2014': 937,
#   'REP votes 2014': 895,
#   'DEM votes 2016': 1817,
#   'REP votes 2016': 1668,
#   'DEM vote share': 0.5179612563475644,
#   'midterm voter percentage': 0.5256814921090387,
#   'DEM missing voters': 856.1899567425239,
#   'REP missing voters': 796.8100432574761,
#   'DEM potential gain': 59.37991348504784},
#  {'Precinct': 'VOL416',
#   'DEM votes 2014': 796,
#   'REP votes 2014': 1001,
#   'DEM votes 2016': 1731,
#   'REP votes 2016': 1331,
#   'DEM vote share': 0.5200658571722576,
#   'midterm voter percentage': 0.5868713259307642,
#   'DEM missing voters': 657.8833093229059,
#   'REP missing voters': 607.1166906770941,
#   'DEM potential gain': 50.76661864581183},
#  {'Precinct': 'VOL405',
#   'DEM votes 2014': 434,
#   'REP votes 2014': 525,
#   'DEM votes 2016': 962,
#   'REP votes 2016': 718,
#   'DEM vote share': 0.5289882531261841,
#   'midterm voter percentage': 0.5708333333333333,
#   'DEM missing voters': 381.40053050397876,
#   'REP missing voters': 339.59946949602124,
#   'DEM potential gain': 41.801061007957514},
#  {'Precinct': 'VOL528',
#   'DEM votes 2014': 481,
#   'REP votes 2014': 318,
#   'DEM votes 2016': 591,
#   'REP votes 2016': 542,
#   'DEM vote share': 0.5548654244306418,
#   'midterm voter percentage': 0.705207413945278,
#   'DEM missing voters': 185.32505175983437,
#   'REP missing voters': 148.67494824016563,
#   'DEM potential gain': 36.65010351966873},
#  {'Precinct': 'VOL626',
#   'DEM votes 2014': 366,
#   'REP votes 2014': 288,
#   'DEM votes 2016': 536,
#   'REP votes 2016': 427,
#   'DEM vote share': 0.5578231292517006,
#   'midterm voter percentage': 0.6791277258566978,
#   'DEM missing voters': 172.36734693877548,
#   'REP missing voters': 136.63265306122452,
#   'DEM potential gain': 35.73469387755097},
#  {'Precinct': 'VOL530',
#   'DEM votes 2014': 543,
#   'REP votes 2014': 423,
#   'DEM votes 2016': 723,
#   'REP votes 2016': 670,
#   'DEM vote share': 0.5366680796947859,
#   'midterm voter percentage': 0.6934673366834171,
#   'DEM missing voters': 229.15727002967358,
#   'REP missing voters': 197.84272997032642,
#   'DEM potential gain': 31.314540059347166},
#  {'Precinct': 'VOL622',
#   'DEM votes 2014': 159,
#   'REP votes 2014': 104,
#   'DEM votes 2016': 244,
#   'REP votes 2016': 190,
#   'DEM vote share': 0.5781922525107605,
#   'midterm voter percentage': 0.6059907834101382,
#   'DEM missing voters': 98.87087517934003,
#   'REP missing voters': 72.12912482065997,
#   'DEM potential gain': 26.741750358680065},
#  {'Precinct': 'VOL410',
#   'DEM votes 2014': 629,
#   'REP votes 2014': 745,
#   'DEM votes 2016': 1235,
#   'REP votes 2016': 1019,
#   'DEM vote share': 0.5137816979051819,
#   'midterm voter percentage': 0.6095829636202307,
#   'DEM missing voters': 452.1278941565601,
#   'REP missing voters': 427.8721058434399,
#   'DEM potential gain': 24.255788313120206},
#  {'Precinct': 'VOL407',
#   'DEM votes 2014': 545,
#   'REP votes 2014': 752,
#   'DEM votes 2016': 1266,
#   'REP votes 2016': 997,
#   'DEM vote share': 0.5087078651685393,
#   'midterm voter percentage': 0.5731330092797172,
#   'DEM missing voters': 491.4117977528089,
#   'REP missing voters': 474.5882022471911,
#   'DEM potential gain': 16.823595505617845},
#  {'Precinct': 'VOL526',
#   'DEM votes 2014': 420,
#   'REP votes 2014': 364,
#   'DEM votes 2016': 586,
#   'REP votes 2016': 594,
#   'DEM vote share': 0.5122199592668024,
#   'midterm voter percentage': 0.6644067796610169,
#   'DEM missing voters': 202.83910386965377,
#   'REP missing voters': 193.16089613034623,
#   'DEM potential gain': 9.678207739307538},
#  {'Precinct': 'VOL623',
#   'DEM votes 2014': 544,
#   'REP votes 2014': 487,
#   'DEM votes 2016': 747,
#   'REP votes 2016': 753,
#   'DEM vote share': 0.5100750691426313,
#   'midterm voter percentage': 0.6873333333333334,
#   'DEM missing voters': 239.2252074278941,
#   'REP missing voters': 229.7747925721059,
#   'DEM potential gain': 9.45041485578821},
#  {'Precinct': 'VOL429',
#   'DEM votes 2014': 354,
#   'REP votes 2014': 446,
#   'DEM votes 2016': 615,
#   'REP votes 2016': 469,
#   'DEM vote share': 0.5143312101910829,
#   'midterm voter percentage': 0.7380073800738007,
#   'DEM missing voters': 146.07006369426753,
#   'REP missing voters': 137.92993630573247,
#   'DEM potential gain': 8.140127388535063},
#  {'Precinct': 'VOL427',
#   'DEM votes 2014': 503,
#   'REP votes 2014': 653,
#   'DEM votes 2016': 1030,
#   'REP votes 2016': 864,
#   'DEM vote share': 0.5026229508196721,
#   'midterm voter percentage': 0.6103484688489969,
#   'DEM missing voters': 370.93573770491804,
#   'REP missing voters': 367.06426229508196,
#   'DEM potential gain': 3.87147540983608},
#  {'Precinct': 'VOL422',
#   'DEM votes 2014': 473,
#   'REP votes 2014': 668,
#   'DEM votes 2016': 1016,
#   'REP votes 2016': 813,
#   'DEM vote share': 0.5013468013468013,
#   'midterm voter percentage': 0.6238381629305632,
#   'DEM missing voters': 344.92659932659933,
#   'REP missing voters': 343.07340067340067,
#   'DEM potential gain': 1.8531986531986604},
#  {'Precinct': 'VOL419',
#   'DEM votes 2014': 245,
#   'REP votes 2014': 363,
#   'DEM votes 2016': 583,
#   'REP votes 2016': 472,
#   'DEM vote share': 0.4978953698135899,
#   'midterm voter percentage': 0.576303317535545,
#   'DEM missing voters': 222.5592303066747,
#   'REP missing voters': 224.44076969332528,
#   'DEM potential gain': -1.8815393866505872},
#  {'Precinct': 'VOL527',
#   'DEM votes 2014': 451,
#   'REP votes 2014': 410,
#   'DEM votes 2016': 549,
#   'REP votes 2016': 627,
#   'DEM vote share': 0.49091801669121254,
#   'midterm voter percentage': 0.7321428571428571,
#   'DEM missing voters': 154.63917525773195,
#   'REP missing voters': 160.36082474226802,
#   'DEM potential gain': -5.721649484536073},
#  {'Precinct': 'VOL417',
#   'DEM votes 2014': 278,
#   'REP votes 2014': 433,
#   'DEM votes 2016': 644,
#   'REP votes 2016': 513,
#   'DEM vote share': 0.493576017130621,
#   'midterm voter percentage': 0.6145203111495247,
#   'DEM missing voters': 220.13490364025697,
#   'REP missing voters': 225.86509635974306,
#   'DEM potential gain': -5.730192719486098},
#  {'Precinct': 'VOL519',
#   'DEM votes 2014': 400,
#   'REP votes 2014': 389,
#   'DEM votes 2016': 489,
#   'REP votes 2016': 551,
#   'DEM vote share': 0.4860579551667578,
#   'midterm voter percentage': 0.7586538461538461,
#   'DEM missing voters': 122.00054674685622,
#   'REP missing voters': 128.99945325314377,
#   'DEM potential gain': -6.998906506287554},
#  {'Precinct': 'VOL809',
#   'DEM votes 2014': 212,
#   'REP votes 2014': 230,
#   'DEM votes 2016': 250,
#   'REP votes 2016': 320,
#   'DEM vote share': 0.45652173913043476,
#   'midterm voter percentage': 0.775438596491228,
#   'DEM missing voters': 58.43478260869565,
#   'REP missing voters': 69.56521739130434,
#   'DEM potential gain': -11.130434782608695},
#  {'Precinct': 'VOL529',
#   'DEM votes 2014': 356,
#   'REP votes 2014': 353,
#   'DEM votes 2016': 548,
#   'REP votes 2016': 610,
#   'DEM vote share': 0.48419925013390464,
#   'midterm voter percentage': 0.6122625215889465,
#   'DEM missing voters': 217.40546331012317,
#   'REP missing voters': 231.59453668987683,
#   'DEM potential gain': -14.189073379753665},
#  {'Precinct': 'VOL218',
#   'DEM votes 2014': 867,
#   'REP votes 2014': 978,
#   'DEM votes 2016': 1510,
#   'REP votes 2016': 1464,
#   'DEM vote share': 0.4932558622120772,
#   'midterm voter percentage': 0.6203765971755212,
#   'DEM missing voters': 556.8858684374351,
#   'REP missing voters': 572.1141315625649,
#   'DEM potential gain': -15.228263125129843},
#  {'Precinct': 'LAK98',
#   'DEM votes 2014': 80,
#   'REP votes 2014': 166,
#   'DEM votes 2016': 114,
#   'REP votes 2016': 187,
#   'DEM vote share': 0.3546617915904936,
#   'midterm voter percentage': 0.8172757475083057,
#   'DEM missing voters': 19.50639853747715,
#   'REP missing voters': 35.493601462522854,
#   'DEM potential gain': -15.987202925045704},
#  {'Precinct': 'VOL403',
#   'DEM votes 2014': 563,
#   'REP votes 2014': 830,
#   'DEM votes 2016': 1245,
#   'REP votes 2016': 1044,
#   'DEM vote share': 0.49103747963063554,
#   'midterm voter percentage': 0.6085626911314985,
#   'DEM missing voters': 439.96958174904944,
#   'REP missing voters': 456.0304182509505,
#   'DEM potential gain': -16.060836501901065},
#  {'Precinct': 'LAK76',
#   'DEM votes 2014': 75,
#   'REP votes 2014': 163,
#   'DEM votes 2016': 121,
#   'REP votes 2016': 178,
#   'DEM vote share': 0.3649906890130354,
#   'midterm voter percentage': 0.7959866220735786,
#   'DEM missing voters': 22.26443202979516,
#   'REP missing voters': 38.73556797020484,
#   'DEM potential gain': -16.47113594040968},
#  {'Precinct': 'LAK8',
#   'DEM votes 2014': 688,
#   'REP votes 2014': 1605,
#   'DEM votes 2016': 761,
#   'REP votes 2016': 1577,
#   'DEM vote share': 0.3128913841502915,
#   'midterm voter percentage': 0.9807527801539777,
#   'DEM missing voters': 14.080112286763118,
#   'REP missing voters': 30.919887713236882,
#   'DEM potential gain': -16.839775426473764},
#  {'Precinct': 'LAK44',
#   'DEM votes 2014': 372,
#   'REP votes 2014': 465,
#   'DEM votes 2016': 603,
#   'REP votes 2016': 606,
#   'DEM vote share': 0.47653958944281527,
#   'midterm voter percentage': 0.6923076923076923,
#   'DEM missing voters': 177.27272727272728,
#   'REP missing voters': 194.72727272727272,
#   'DEM potential gain': -17.45454545454544},
#  {'Precinct': 'VOL523',
#   'DEM votes 2014': 543,
#   'REP votes 2014': 464,
#   'DEM votes 2016': 741,
#   'REP votes 2016': 894,
#   'DEM vote share': 0.48599545798637395,
#   'midterm voter percentage': 0.6159021406727829,
#   'DEM missing voters': 305.20514761544285,
#   'REP missing voters': 322.7948523845572,
#   'DEM potential gain': -17.58970476911435},
#  {'Precinct': 'VOL223',
#   'DEM votes 2014': 73,
#   'REP votes 2014': 140,
#   'DEM votes 2016': 140,
#   'REP votes 2016': 172,
#   'DEM vote share': 0.4057142857142857,
#   'midterm voter percentage': 0.6826923076923077,
#   'DEM missing voters': 40.16571428571429,
#   'REP missing voters': 58.83428571428571,
#   'DEM potential gain': -18.668571428571425},
#  {'Precinct': 'VOL810',
#   'DEM votes 2014': 443,
#   'REP votes 2014': 443,
#   'DEM votes 2016': 566,
#   'REP votes 2016': 680,
#   'DEM vote share': 0.4732645403377111,
#   'midterm voter percentage': 0.7110754414125201,
#   'DEM missing voters': 170.375234521576,
#   'REP missing voters': 189.624765478424,
#   'DEM potential gain': -19.24953095684799},
#  {'Precinct': 'LAK53',
#   'DEM votes 2014': 126,
#   'REP votes 2014': 139,
#   'DEM votes 2016': 152,
#   'REP votes 2016': 249,
#   'DEM vote share': 0.4174174174174174,
#   'midterm voter percentage': 0.6608478802992519,
#   'DEM missing voters': 56.768768768768766,
#   'REP missing voters': 79.23123123123122,
#   'DEM potential gain': -22.462462462462454},
#  {'Precinct': 'LAK6',
#   'DEM votes 2014': 580,
#   'REP votes 2014': 709,
#   'DEM votes 2016': 942,
#   'REP votes 2016': 942,
#   'DEM vote share': 0.4796722344784116,
#   'midterm voter percentage': 0.6841825902335457,
#   'DEM missing voters': 285.40497951465494,
#   'REP missing voters': 309.59502048534506,
#   'DEM potential gain': -24.19004097069012},
#  {'Precinct': 'VOL720',
#   'DEM votes 2014': 217,
#   'REP votes 2014': 270,
#   'DEM votes 2016': 230,
#   'REP votes 2016': 390,
#   'DEM vote share': 0.4037940379403794,
#   'midterm voter percentage': 0.785483870967742,
#   'DEM missing voters': 53.70460704607046,
#   'REP missing voters': 79.29539295392954,
#   'DEM potential gain': -25.59078590785908},
#  {'Precinct': 'LAK66',
#   'DEM votes 2014': 312,
#   'REP votes 2014': 453,
#   'DEM votes 2016': 482,
#   'REP votes 2016': 538,
#   'DEM vote share': 0.4448179271708683,
#   'midterm voter percentage': 0.75,
#   'DEM missing voters': 113.42857142857142,
#   'REP missing voters': 141.57142857142858,
#   'DEM potential gain': -28.142857142857167},
#  {'Precinct': 'VOL423',
#   'DEM votes 2014': 402,
#   'REP votes 2014': 606,
#   'DEM votes 2016': 872,
#   'REP votes 2016': 788,
#   'DEM vote share': 0.4775112443778111,
#   'midterm voter percentage': 0.6072289156626506,
#   'DEM missing voters': 311.3373313343329,
#   'REP missing voters': 340.6626686656671,
#   'DEM potential gain': -29.325337331334254},
#  {'Precinct': 'FLA1',
#   'DEM votes 2014': 315,
#   'REP votes 2014': 349,
#   'DEM votes 2016': 467,
#   'REP votes 2016': 570,
#   'DEM vote share': 0.45972957084068194,
#   'midterm voter percentage': 0.6403085824493732,
#   'DEM missing voters': 171.47912992357436,
#   'REP missing voters': 201.52087007642567,
#   'DEM potential gain': -30.041740152851304},
#  {'Precinct': 'VOL807',
#   'DEM votes 2014': 513,
#   'REP votes 2014': 538,
#   'DEM votes 2016': 536,
#   'REP votes 2016': 782,
#   'DEM vote share': 0.4428028704094555,
#   'midterm voter percentage': 0.7974203338391502,
#   'DEM missing voters': 118.22836639932461,
#   'REP missing voters': 148.77163360067536,
#   'DEM potential gain': -30.543267201350744},
#  {'Precinct': 'VOL413',
#   'DEM votes 2014': 469,
#   'REP votes 2014': 623,
#   'DEM votes 2016': 918,
#   'REP votes 2016': 894,
#   'DEM vote share': 0.4776170798898072,
#   'midterm voter percentage': 0.6026490066225165,
#   'DEM missing voters': 343.88429752066116,
#   'REP missing voters': 376.11570247933884,
#   'DEM potential gain': -32.23140495867767},
#  {'Precinct': 'VOL415',
#   'DEM votes 2014': 472,
#   'REP votes 2014': 779,
#   'DEM votes 2016': 1211,
#   'REP votes 2016': 1024,
#   'DEM vote share': 0.4827882960413081,
#   'midterm voter percentage': 0.5597315436241611,
#   'DEM missing voters': 475.06368330464716,
#   'REP missing voters': 508.9363166953528,
#   'DEM potential gain': -33.87263339070563},
#  {'Precinct': 'VOL212',
#   'DEM votes 2014': 819,
#   'REP votes 2014': 931,
#   'DEM votes 2016': 1169,
#   'REP votes 2016': 1271,
#   'DEM vote share': 0.4744630071599045,
#   'midterm voter percentage': 0.7172131147540983,
#   'DEM missing voters': 327.37947494033415,
#   'REP missing voters': 362.62052505966585,
#   'DEM potential gain': -35.2410501193317},
#  {'Precinct': 'LAK58',
#   'DEM votes 2014': 221,
#   'REP votes 2014': 332,
#   'DEM votes 2016': 333,
#   'REP votes 2016': 438,
#   'DEM vote share': 0.41842900302114805,
#   'midterm voter percentage': 0.7172503242542153,
#   'DEM missing voters': 91.21752265861028,
#   'REP missing voters': 126.78247734138972,
#   'DEM potential gain': -35.564954682779444},
#  {'Precinct': 'VOL515',
#   'DEM votes 2014': 661,
#   'REP votes 2014': 716,
#   'DEM votes 2016': 978,
#   'REP votes 2016': 1101,
#   'DEM vote share': 0.4742476851851852,
#   'midterm voter percentage': 0.6623376623376623,
#   'DEM missing voters': 332.921875,
#   'REP missing voters': 369.07812500000006,
#   'DEM potential gain': -36.15625000000006},
#  {'Precinct': 'FLA15',
#   'DEM votes 2014': 587,
#   'REP votes 2014': 599,
#   'DEM votes 2016': 902,
#   'REP votes 2016': 1044,
#   'DEM vote share': 0.47541507024265645,
#   'midterm voter percentage': 0.6094552929085303,
#   'DEM missing voters': 361.3154533844189,
#   'REP missing voters': 398.68454661558104,
#   'DEM potential gain': -37.36909323116214},
#  {'Precinct': 'FLA16',
#   'DEM votes 2014': 446,
#   'REP votes 2014': 485,
#   'DEM votes 2016': 683,
#   'REP votes 2016': 807,
#   'DEM vote share': 0.466336224700537,
#   'midterm voter percentage': 0.6248322147651006,
#   'DEM missing voters': 260.6819496076002,
#   'REP missing voters': 298.31805039239987,
#   'DEM potential gain': -37.63610078479968},
#  {'Precinct': 'LAK20',
#   'DEM votes 2014': 246,
#   'REP votes 2014': 416,
#   'DEM votes 2016': 339,
#   'REP votes 2016': 499,
#   'DEM vote share': 0.39,
#   'midterm voter percentage': 0.7899761336515513,
#   'DEM missing voters': 68.64,
#   'REP missing voters': 107.36,
#   'DEM potential gain': -38.72},
#  {'Precinct': 'FLA11',
#   'DEM votes 2014': 586,
#   'REP votes 2014': 591,
#   'DEM votes 2016': 930,
#   'REP votes 2016': 1082,
#   'DEM vote share': 0.47538413295703985,
#   'midterm voter percentage': 0.5849900596421471,
#   'DEM missing voters': 396.9457510191283,
#   'REP missing voters': 438.0542489808717,
#   'DEM potential gain': -41.10849796174341},
#  {'Precinct': 'VOL910',
#   'DEM votes 2014': 293,
#   'REP votes 2014': 348,
#   'DEM votes 2016': 354,
#   'REP votes 2016': 547,
#   'DEM vote share': 0.41958495460440987,
#   'midterm voter percentage': 0.7114317425083241,
#   'DEM missing voters': 109.09208819714657,
#   'REP missing voters': 150.90791180285342,
#   'DEM potential gain': -41.81582360570685},
#  {'Precinct': 'LAK104',
#   'DEM votes 2014': 213,
#   'REP votes 2014': 351,
#   'DEM votes 2016': 280,
#   'REP votes 2016': 458,
#   'DEM vote share': 0.37864823348694315,
#   'midterm voter percentage': 0.7642276422764228,
#   'DEM missing voters': 65.88479262672811,
#   'REP missing voters': 108.11520737327189,
#   'DEM potential gain': -42.23041474654377},
#  {'Precinct': 'FLA13',
#   'DEM votes 2014': 575,
#   'REP votes 2014': 644,
#   'DEM votes 2016': 967,
#   'REP votes 2016': 1069,
#   'DEM vote share': 0.4737327188940092,
#   'midterm voter percentage': 0.5987229862475442,
#   'DEM missing voters': 387.03963133640553,
#   'REP missing voters': 429.96036866359447,
#   'DEM potential gain': -42.92073732718893},
#  {'Precinct': 'VOL414',
#   'DEM votes 2014': 518,
#   'REP votes 2014': 789,
#   'DEM votes 2016': 1018,
#   'REP votes 2016': 983,
#   'DEM vote share': 0.46432889963724305,
#   'midterm voter percentage': 0.6531734132933533,
#   'DEM missing voters': 322.24425634824667,
#   'REP missing voters': 371.75574365175333,
#   'DEM potential gain': -49.51148730350667},
#  {'Precinct': 'FLA20',
#   'DEM votes 2014': 428,
#   'REP votes 2014': 522,
#   'DEM votes 2016': 617,
#   'REP votes 2016': 785,
#   'DEM vote share': 0.4443027210884354,
#   'midterm voter percentage': 0.6776034236804565,
#   'DEM missing voters': 200.8248299319728,
#   'REP missing voters': 251.1751700680272,
#   'DEM potential gain': -50.3503401360544},
#  {'Precinct': 'VOL105',
#   'DEM votes 2014': 108,
#   'REP votes 2014': 234,
#   'DEM votes 2016': 219,
#   'REP votes 2016': 320,
#   'DEM vote share': 0.3711691259931896,
#   'midterm voter percentage': 0.634508348794063,
#   'DEM missing voters': 73.12031782065834,
#   'REP missing voters': 123.87968217934167,
#   'DEM potential gain': -50.75936435868333},
#  {'Precinct': 'VOL203',
#   'DEM votes 2014': 83,
#   'REP votes 2014': 198,
#   'DEM votes 2016': 130,
#   'REP votes 2016': 283,
#   'DEM vote share': 0.3069164265129683,
#   'midterm voter percentage': 0.6803874092009685,
#   'DEM missing voters': 40.512968299711815,
#   'REP missing voters': 91.48703170028818,
#   'DEM potential gain': -50.97406340057637},
#  {'Precinct': 'VOL901',
#   'DEM votes 2014': 523,
#   'REP votes 2014': 577,
#   'DEM votes 2016': 628,
#   'REP votes 2016': 894,
#   'DEM vote share': 0.43897787948131195,
#   'midterm voter percentage': 0.7227332457293035,
#   'DEM missing voters': 185.24866514111363,
#   'REP missing voters': 236.75133485888637,
#   'DEM potential gain': -51.50266971777273},
#  {'Precinct': 'VOL204',
#   'DEM votes 2014': 141,
#   'REP votes 2014': 244,
#   'DEM votes 2016': 211,
#   'REP votes 2016': 367,
#   'DEM vote share': 0.3655244029075805,
#   'midterm voter percentage': 0.6660899653979239,
#   'DEM missing voters': 70.54620976116303,
#   'REP missing voters': 122.45379023883697,
#   'DEM potential gain': -51.907580477673946},
#  {'Precinct': 'VOL509',
#   'DEM votes 2014': 234,
#   'REP votes 2014': 455,
#   'DEM votes 2016': 278,
#   'REP votes 2016': 569,
#   'DEM vote share': 0.3333333333333333,
#   'midterm voter percentage': 0.8134592680047226,
#   'DEM missing voters': 52.666666666666664,
#   'REP missing voters': 105.33333333333334,
#   'DEM potential gain': -52.66666666666668},
#  {'Precinct': 'FLA5',
#   'DEM votes 2014': 77,
#   'REP votes 2014': 167,
#   'DEM votes 2016': 92,
#   'REP votes 2016': 273,
#   'DEM vote share': 0.277504105090312,
#   'midterm voter percentage': 0.6684931506849315,
#   'DEM missing voters': 33.57799671592775,
#   'REP missing voters': 87.42200328407225,
#   'DEM potential gain': -53.84400656814449},
#  {'Precinct': 'FLA17',
#   'DEM votes 2014': 343,
#   'REP votes 2014': 415,
#   'DEM votes 2016': 502,
#   'REP votes 2016': 682,
#   'DEM vote share': 0.4351184346035015,
#   'midterm voter percentage': 0.6402027027027027,
#   'DEM missing voters': 185.36045314109165,
#   'REP missing voters': 240.63954685890835,
#   'DEM potential gain': -55.27909371781669},
#  {'Precinct': 'VOL722',
#   'DEM votes 2014': 584,
#   'REP votes 2014': 617,
#   'DEM votes 2016': 766,
#   'REP votes 2016': 1021,
#   'DEM vote share': 0.45180722891566266,
#   'midterm voter percentage': 0.672076105204253,
#   'DEM missing voters': 264.7590361445783,
#   'REP missing voters': 321.2409638554216,
#   'DEM potential gain': -56.48192771084331},
#  {'Precinct': 'LAK2',
#   'DEM votes 2014': 76,
#   'REP votes 2014': 224,
#   'DEM votes 2016': 111,
#   'REP votes 2016': 311,
#   'DEM vote share': 0.2590027700831025,
#   'midterm voter percentage': 0.7109004739336493,
#   'DEM missing voters': 31.598337950138507,
#   'REP missing voters': 90.40166204986149,
#   'DEM potential gain': -58.80332409972298},
#  {'Precinct': 'LAK36',
#   'DEM votes 2014': 312,
#   'REP votes 2014': 569,
#   'DEM votes 2016': 480,
#   'REP votes 2016': 679,
#   'DEM vote share': 0.38823529411764707,
#   'midterm voter percentage': 0.7601380500431406,
#   'DEM missing voters': 107.92941176470589,
#   'REP missing voters': 170.07058823529414,
#   'DEM potential gain': -62.14117647058825},
#  {'Precinct': 'VOL703',
#   'DEM votes 2014': 820,
#   'REP votes 2014': 907,
#   'DEM votes 2016': 1229,
#   'REP votes 2016': 1440,
#   'DEM vote share': 0.46610555050045493,
#   'midterm voter percentage': 0.6470588235294118,
#   'DEM missing voters': 439.07142857142856,
#   'REP missing voters': 502.9285714285714,
#   'DEM potential gain': -63.85714285714283},
#  {'Precinct': 'VOL625',
#   'DEM votes 2014': 373,
#   'REP votes 2014': 553,
#   'DEM votes 2016': 452,
#   'REP votes 2016': 765,
#   'DEM vote share': 0.3849743350443304,
#   'midterm voter percentage': 0.7608874281018899,
#   'DEM missing voters': 112.02753149790014,
#   'REP missing voters': 178.97246850209984,
#   'DEM potential gain': -66.9449370041997},
#  {'Precinct': 'LAK54',
#   'DEM votes 2014': 192,
#   'REP votes 2014': 353,
#   'DEM votes 2016': 233,
#   'REP votes 2016': 513,
#   'DEM vote share': 0.3292021688613478,
#   'midterm voter percentage': 0.7305630026809652,
#   'DEM missing voters': 66.1696359411309,
#   'REP missing voters': 134.8303640588691,
#   'DEM potential gain': -68.66072811773819},
#  {'Precinct': 'VOL701',
#   'DEM votes 2014': 1064,
#   'REP votes 2014': 1188,
#   'DEM votes 2016': 1338,
#   'REP votes 2016': 1693,
#   'DEM vote share': 0.4546659095211054,
#   'midterm voter percentage': 0.742989112504124,
#   'DEM missing voters': 354.1847435169411,
#   'REP missing voters': 424.8152564830589,
#   'DEM potential gain': -70.63051296611775},
#  {'Precinct': 'LAK43',
#   'DEM votes 2014': 810,
#   'REP votes 2014': 1036,
#   'DEM votes 2016': 1227,
#   'REP votes 2016': 1404,
#   'DEM vote share': 0.45499218226490956,
#   'midterm voter percentage': 0.701634359559103,
#   'DEM missing voters': 357.16886307795403,
#   'REP missing voters': 427.83113692204597,
#   'DEM potential gain': -70.66227384409194},
#  {'Precinct': 'VOL717',
#   'DEM votes 2014': 395,
#   'REP votes 2014': 427,
#   'DEM votes 2016': 574,
#   'REP votes 2016': 818,
#   'DEM vote share': 0.43766937669376693,
#   'midterm voter percentage': 0.5905172413793104,
#   'DEM missing voters': 249.47154471544715,
#   'REP missing voters': 320.5284552845529,
#   'DEM potential gain': -71.05691056910572},
#  {'Precinct': 'VOL638',
#   'DEM votes 2014': 493,
#   'REP votes 2014': 591,
#   'DEM votes 2016': 670,
#   'REP votes 2016': 938,
#   'DEM vote share': 0.4320208023774146,
#   'midterm voter percentage': 0.6741293532338308,
#   'DEM missing voters': 226.37890044576525,
#   'REP missing voters': 297.6210995542348,
#   'DEM potential gain': -71.24219910846952},
#  {'Precinct': 'VOL719',
#   'DEM votes 2014': 480,
#   'REP votes 2014': 546,
#   'DEM votes 2016': 552,
#   'REP votes 2016': 904,
#   'DEM vote share': 0.41579371474617244,
#   'midterm voter percentage': 0.7046703296703297,
#   'DEM missing voters': 178.79129734085416,
#   'REP missing voters': 251.20870265914584,
#   'DEM potential gain': -72.41740531829169},
#  {'Precinct': 'VOL712',
#   'DEM votes 2014': 429,
#   'REP votes 2014': 505,
#   'DEM votes 2016': 586,
#   'REP votes 2016': 858,
#   'DEM vote share': 0.4268292682926829,
#   'midterm voter percentage': 0.646814404432133,
#   'DEM missing voters': 217.6829268292683,
#   'REP missing voters': 292.31707317073176,
#   'DEM potential gain': -74.63414634146346},
#  {'Precinct': 'VOL504',
#   'DEM votes 2014': 527,
#   'REP votes 2014': 651,
#   'DEM votes 2016': 689,
#   'REP votes 2016': 991,
#   'DEM vote share': 0.42547235829251223,
#   'midterm voter percentage': 0.7011904761904761,
#   'DEM missing voters': 213.58712386284114,
#   'REP missing voters': 288.4128761371589,
#   'DEM potential gain': -74.82575227431775},
#  {'Precinct': 'FLA19',
#   'DEM votes 2014': 954,
#   'REP votes 2014': 1049,
#   'DEM votes 2016': 1352,
#   'REP votes 2016': 1637,
#   'DEM vote share': 0.4619391025641026,
#   'midterm voter percentage': 0.6701237872198059,
#   'DEM missing voters': 455.47195512820514,
#   'REP missing voters': 530.5280448717948,
#   'DEM potential gain': -75.05608974358967},
#  {'Precinct': 'FLA35',
#   'DEM votes 2014': 409,
#   'REP votes 2014': 591,
#   'DEM votes 2016': 507,
#   'REP votes 2016': 838,
#   'DEM vote share': 0.3906183368869936,
#   'midterm voter percentage': 0.7434944237918215,
#   'DEM missing voters': 134.7633262260128,
#   'REP missing voters': 210.23667377398723,
#   'DEM potential gain': -75.47334754797444},
#  {'Precinct': 'VOL909',
#   'DEM votes 2014': 340,
#   'REP votes 2014': 431,
#   'DEM votes 2016': 401,
#   'REP votes 2016': 720,
#   'DEM vote share': 0.3916490486257928,
#   'midterm voter percentage': 0.687778768956289,
#   'DEM missing voters': 137.07716701902748,
#   'REP missing voters': 212.9228329809725,
#   'DEM potential gain': -75.845665961945},
#  {'Precinct': 'VOL705',
#   'DEM votes 2014': 309,
#   'REP votes 2014': 476,
#   'DEM votes 2016': 359,
#   'REP votes 2016': 701,
#   'DEM vote share': 0.36205962059620594,
#   'midterm voter percentage': 0.7405660377358491,
#   'DEM missing voters': 99.56639566395664,
#   'REP missing voters': 175.43360433604337,
#   'DEM potential gain': -75.86720867208673},
#  {'Precinct': 'VOL101',
#   'DEM votes 2014': 168,
#   'REP votes 2014': 332,
#   'DEM votes 2016': 237,
#   'REP votes 2016': 492,
#   'DEM vote share': 0.3295362082994304,
#   'midterm voter percentage': 0.6858710562414266,
#   'DEM missing voters': 75.46379170056957,
#   'REP missing voters': 153.53620829943043,
#   'DEM potential gain': -78.07241659886085},
#  {'Precinct': 'LAK1',
#   'DEM votes 2014': 231,
#   'REP votes 2014': 440,
#   'DEM votes 2016': 303,
#   'REP votes 2016': 613,
#   'DEM vote share': 0.33648393194706994,
#   'midterm voter percentage': 0.732532751091703,
#   'DEM missing voters': 82.43856332703213,
#   'REP missing voters': 162.56143667296786,
#   'DEM potential gain': -80.12287334593573},
#  {'Precinct': 'LAK86',
#   'DEM votes 2014': 193,
#   'REP votes 2014': 699,
#   'DEM votes 2016': 282,
#   'REP votes 2016': 769,
#   'DEM vote share': 0.2444673185795162,
#   'midterm voter percentage': 0.8487155090390105,
#   'DEM missing voters': 38.87030365414308,
#   'REP missing voters': 120.12969634585693,
#   'DEM potential gain': -81.25939269171386},
#  {'Precinct': 'VOL205',
#   'DEM votes 2014': 348,
#   'REP votes 2014': 522,
#   'DEM votes 2016': 464,
#   'REP votes 2016': 770,
#   'DEM vote share': 0.38593155893536124,
#   'midterm voter percentage': 0.7050243111831442,
#   'DEM missing voters': 140.4790874524715,
#   'REP missing voters': 223.5209125475285,
#   'DEM potential gain': -83.04182509505699},
#  {'Precinct': 'VOL411',
#   'DEM votes 2014': 513,
#   'REP votes 2014': 766,
#   'DEM votes 2016': 1026,
#   'REP votes 2016': 1110,
#   'DEM vote share': 0.45065885797950217,
#   'midterm voter percentage': 0.5987827715355806,
#   'DEM missing voters': 386.21464128843337,
#   'REP missing voters': 470.7853587115667,
#   'DEM potential gain': -84.57071742313332},
#  {'Precinct': 'VOL812',
#   'DEM votes 2014': 661,
#   'REP votes 2014': 885,
#   'DEM votes 2016': 915,
#   'REP votes 2016': 1220,
#   'DEM vote share': 0.42814452594403696,
#   'midterm voter percentage': 0.7241217798594848,
#   'DEM missing voters': 252.17712578103777,
#   'REP missing voters': 336.8228742189622,
#   'DEM potential gain': -84.64574843792445},
#  {'Precinct': 'VOL607',
#   'DEM votes 2014': 981,
#   'REP votes 2014': 1097,
#   'DEM votes 2016': 1273,
#   'REP votes 2016': 1659,
#   'DEM vote share': 0.4499001996007984,
#   'midterm voter percentage': 0.708731241473397,
#   'DEM missing voters': 384.2147704590818,
#   'REP missing voters': 469.7852295409182,
#   'DEM potential gain': -85.57045908183636},
#  {'Precinct': 'VOL503',
#   'DEM votes 2014': 205,
#   'REP votes 2014': 469,
#   'DEM votes 2016': 274,
#   'REP votes 2016': 626,
#   'DEM vote share': 0.30432020330368487,
#   'midterm voter percentage': 0.7488888888888889,
#   'DEM missing voters': 68.77636594663278,
#   'REP missing voters': 157.22363405336722,
#   'DEM potential gain': -88.44726810673444},
#  {'Precinct': 'VOL401',
#   'DEM votes 2014': 807,
#   'REP votes 2014': 1391,
#   'DEM votes 2016': 1732,
#   'REP votes 2016': 1596,
#   'DEM vote share': 0.45946435034382915,
#   'midterm voter percentage': 0.6604567307692307,
#   'DEM missing voters': 519.194715888527,
#   'REP missing voters': 610.805284111473,
#   'DEM potential gain': -91.61056822294609},
#  {'Precinct': 'VOL517',
#   'DEM votes 2014': 491,
#   'REP votes 2014': 681,
#   'DEM votes 2016': 653,
#   'REP votes 2016': 1006,
#   'DEM vote share': 0.40409749205227835,
#   'midterm voter percentage': 0.7064496684749849,
#   'DEM missing voters': 196.79547862945955,
#   'REP missing voters': 290.2045213705404,
#   'DEM potential gain': -93.40904274108087},
#  {'Precinct': 'VOL222',
#   'DEM votes 2014': 581,
#   'REP votes 2014': 733,
#   'DEM votes 2016': 732,
#   'REP votes 2016': 1128,
#   'DEM vote share': 0.4136735979836169,
#   'midterm voter percentage': 0.7064516129032258,
#   'DEM missing voters': 225.86578449905483,
#   'REP missing voters': 320.1342155009452,
#   'DEM potential gain': -94.26843100189035},
#  {'Precinct': 'VOL511',
#   'DEM votes 2014': 160,
#   'REP votes 2014': 308,
#   'DEM votes 2016': 185,
#   'REP votes 2016': 517,
#   'DEM vote share': 0.2948717948717949,
#   'midterm voter percentage': 0.6666666666666666,
#   'DEM missing voters': 69.0,
#   'REP missing voters': 164.99999999999997,
#   'DEM potential gain': -95.99999999999997},
#  {'Precinct': 'FLA18',
#   'DEM votes 2014': 1484,
#   'REP votes 2014': 1676,
#   'DEM votes 2016': 1976,
#   'REP votes 2016': 2408,
#   'DEM vote share': 0.4586426299045599,
#   'midterm voter percentage': 0.7208029197080292,
#   'DEM missing voters': 561.3785790031814,
#   'REP missing voters': 662.6214209968188,
#   'DEM potential gain': -101.2428419936374},
#  {'Precinct': 'LAK33',
#   'DEM votes 2014': 190,
#   'REP votes 2014': 441,
#   'DEM votes 2016': 268,
#   'REP votes 2016': 619,
#   'DEM vote share': 0.30171277997364954,
#   'midterm voter percentage': 0.7113866967305524,
#   'DEM missing voters': 77.23847167325428,
#   'REP missing voters': 178.76152832674572,
#   'DEM potential gain': -101.52305665349144},
#  {'Precinct': 'LAK31',
#   'DEM votes 2014': 325,
#   'REP votes 2014': 637,
#   'DEM votes 2016': 554,
#   'REP votes 2016': 823,
#   'DEM vote share': 0.3758016246259085,
#   'midterm voter percentage': 0.6986201888162672,
#   'DEM missing voters': 155.95767421975202,
#   'REP missing voters': 259.04232578024795,
#   'DEM potential gain': -103.08465156049593},
#  {'Precinct': 'VOL420',
#   'DEM votes 2014': 555,
#   'REP votes 2014': 932,
#   'DEM votes 2016': 1195,
#   'REP votes 2016': 1248,
#   'DEM vote share': 0.44529262086513993,
#   'midterm voter percentage': 0.6086778550961932,
#   'DEM missing voters': 425.6997455470738,
#   'REP missing voters': 530.3002544529262,
#   'DEM potential gain': -104.6005089058524},
#  {'Precinct': 'FLA14',
#   'DEM votes 2014': 558,
#   'REP votes 2014': 684,
#   'DEM votes 2016': 853,
#   'REP votes 2016': 1168,
#   'DEM vote share': 0.43242414955562364,
#   'midterm voter percentage': 0.6145472538347353,
#   'DEM missing voters': 336.85841250383083,
#   'REP missing voters': 442.1415874961692,
#   'DEM potential gain': -105.28317499233839},
#  {'Precinct': 'VOL521',
#   'DEM votes 2014': 1009,
#   'REP votes 2014': 1507,
#   'DEM votes 2016': 1118,
#   'REP votes 2016': 1865,
#   'DEM vote share': 0.386797599563557,
#   'midterm voter percentage': 0.8434461951055984,
#   'DEM missing voters': 180.63447899618114,
#   'REP missing voters': 286.36552100381886,
#   'DEM potential gain': -105.73104200763771},
#  {'Precinct': 'VOL506',
#   'DEM votes 2014': 636,
#   'REP votes 2014': 1029,
#   'DEM votes 2016': 792,
#   'REP votes 2016': 1314,
#   'DEM vote share': 0.3786793953858393,
#   'midterm voter percentage': 0.7905982905982906,
#   'DEM missing voters': 166.99761336515513,
#   'REP missing voters': 274.00238663484487,
#   'DEM potential gain': -107.00477326968974},
#  {'Precinct': 'VOL406',
#   'DEM votes 2014': 877,
#   'REP votes 2014': 1414,
#   'DEM votes 2016': 1810,
#   'REP votes 2016': 1765,
#   'DEM vote share': 0.4580634162973065,
#   'midterm voter percentage': 0.6408391608391608,
#   'DEM missing voters': 588.1534265257416,
#   'REP missing voters': 695.8465734742584,
#   'DEM potential gain': -107.69314694851687},
#  {'Precinct': 'VOL725',
#   'DEM votes 2014': 487,
#   'REP votes 2014': 800,
#   'DEM votes 2016': 602,
#   'REP votes 2016': 1095,
#   'DEM vote share': 0.36494638069705093,
#   'midterm voter percentage': 0.7583971714790807,
#   'DEM missing voters': 149.62801608579088,
#   'REP missing voters': 260.37198391420907,
#   'DEM potential gain': -110.74396782841819},
#  {'Precinct': 'VOL206',
#   'DEM votes 2014': 530,
#   'REP votes 2014': 834,
#   'DEM votes 2016': 774,
#   'REP votes 2016': 1146,
#   'DEM vote share': 0.39707673568818513,
#   'midterm voter percentage': 0.7104166666666667,
#   'DEM missing voters': 220.77466504263094,
#   'REP missing voters': 335.22533495736906,
#   'DEM potential gain': -114.45066991473811},
#  {'Precinct': 'VOL714',
#   'DEM votes 2014': 777,
#   'REP votes 2014': 941,
#   'DEM votes 2016': 1083,
#   'REP votes 2016': 1494,
#   'DEM vote share': 0.4330616996507567,
#   'midterm voter percentage': 0.6666666666666666,
#   'DEM missing voters': 372.0,
#   'REP missing voters': 487.0,
#   'DEM potential gain': -115.0},
#  {'Precinct': 'LAK3',
#   'DEM votes 2014': 224,
#   'REP votes 2014': 482,
#   'DEM votes 2016': 275,
#   'REP votes 2016': 712,
#   'DEM vote share': 0.2947430596574129,
#   'midterm voter percentage': 0.7152988855116514,
#   'DEM missing voters': 82.82279976373302,
#   'REP missing voters': 198.17720023626697,
#   'DEM potential gain': -115.35440047253395},
#  {'Precinct': 'VOL709',
#   'DEM votes 2014': 698,
#   'REP votes 2014': 815,
#   'DEM votes 2016': 948,
#   'REP votes 2016': 1377,
#   'DEM vote share': 0.42886920270974466,
#   'midterm voter percentage': 0.650752688172043,
#   'DEM missing voters': 348.24179260031264,
#   'REP missing voters': 463.7582073996873,
#   'DEM potential gain': -115.51641479937467},
#  {'Precinct': 'VOL813',
#   'DEM votes 2014': 424,
#   'REP votes 2014': 697,
#   'DEM votes 2016': 539,
#   'REP votes 2016': 1004,
#   'DEM vote share': 0.3614864864864865,
#   'midterm voter percentage': 0.7265068049254698,
#   'DEM missing voters': 152.54729729729732,
#   'REP missing voters': 269.4527027027027,
#   'DEM potential gain': -116.90540540540539},
#  {'Precinct': 'VOL733',
#   'DEM votes 2014': 538,
#   'REP votes 2014': 899,
#   'DEM votes 2016': 703,
#   'REP votes 2016': 1219,
#   'DEM vote share': 0.3694551949985115,
#   'midterm voter percentage': 0.7476586888657648,
#   'DEM missing voters': 179.18576957427805,
#   'REP missing voters': 305.814230425722,
#   'DEM potential gain': -126.62846085144392},
#  {'Precinct': 'VOL309',
#   'DEM votes 2014': 548,
#   'REP votes 2014': 1062,
#   'DEM votes 2016': 1358,
#   'REP votes 2016': 1345,
#   'DEM vote share': 0.4419197774171111,
#   'midterm voter percentage': 0.5956344802071772,
#   'DEM missing voters': 483.0183167169024,
#   'REP missing voters': 609.9816832830976,
#   'DEM potential gain': -126.96336656619519},
#  {'Precinct': 'STJ209',
#   'DEM votes 2014': 613,
#   'REP votes 2014': 799,
#   'DEM votes 2016': 893,
#   'REP votes 2016': 1306,
#   'DEM vote share': 0.4170589864303517,
#   'midterm voter percentage': 0.6421100500227376,
#   'DEM missing voters': 328.2254223206868,
#   'REP missing voters': 458.77457767931315,
#   'DEM potential gain': -130.54915535862636},
#  {'Precinct': 'VOL711',
#   'DEM votes 2014': 867,
#   'REP votes 2014': 954,
#   'DEM votes 2016': 1198,
#   'REP votes 2016': 1689,
#   'DEM vote share': 0.4386151231945625,
#   'midterm voter percentage': 0.6307585729130586,
#   'DEM missing voters': 467.5637213254036,
#   'REP missing voters': 598.4362786745963,
#   'DEM potential gain': -130.87255734919273},
#  {'Precinct': 'VOL421',
#   'DEM votes 2014': 397,
#   'REP votes 2014': 1072,
#   'DEM votes 2016': 675,
#   'REP votes 2016': 1170,
#   'DEM vote share': 0.32347616173808086,
#   'midterm voter percentage': 0.7962059620596206,
#   'DEM missing voters': 121.6270368135184,
#   'REP missing voters': 254.37296318648163,
#   'DEM potential gain': -132.74592637296323},
#  {'Precinct': 'VOL814',
#   'DEM votes 2014': 534,
#   'REP votes 2014': 787,
#   'DEM votes 2016': 658,
#   'REP votes 2016': 1197,
#   'DEM vote share': 0.37531486146095716,
#   'midterm voter percentage': 0.7121293800539084,
#   'DEM missing voters': 200.4181360201511,
#   'REP missing voters': 333.5818639798489,
#   'DEM potential gain': -133.16372795969778},
#  {'Precinct': 'VOL207',
#   'DEM votes 2014': 495,
#   'REP votes 2014': 956,
#   'DEM votes 2016': 654,
#   'REP votes 2016': 1240,
#   'DEM vote share': 0.3434977578475336,
#   'midterm voter percentage': 0.76610348468849,
#   'DEM missing voters': 152.1695067264574,
#   'REP missing voters': 290.83049327354263,
#   'DEM potential gain': -138.66098654708523},
#  {'Precinct': 'VOL718',
#   'DEM votes 2014': 809,
#   'REP votes 2014': 1041,
#   'DEM votes 2016': 1066,
#   'REP votes 2016': 1601,
#   'DEM vote share': 0.4150985167146336,
#   'midterm voter percentage': 0.693663292088489,
#   'DEM missing voters': 339.1354881558556,
#   'REP missing voters': 477.8645118441444,
#   'DEM potential gain': -138.72902368828875},
#  {'Precinct': 'VOL516',
#   'DEM votes 2014': 526,
#   'REP votes 2014': 972,
#   'DEM votes 2016': 659,
#   'REP votes 2016': 1292,
#   'DEM vote share': 0.34357784865178315,
#   'midterm voter percentage': 0.7678113787801127,
#   'DEM missing voters': 155.64076543925776,
#   'REP missing voters': 297.35923456074227,
#   'DEM potential gain': -141.7184691214845},
#  {'Precinct': 'VOL641',
#   'DEM votes 2014': 981,
#   'REP votes 2014': 1349,
#   'DEM votes 2016': 1389,
#   'REP votes 2016': 1874,
#   'DEM vote share': 0.42374396567137496,
#   'midterm voter percentage': 0.7140668096843396,
#   'DEM missing voters': 395.35311997139286,
#   'REP missing voters': 537.6468800286071,
#   'DEM potential gain': -142.29376005721429},
#  {'Precinct': 'LAK91',
#   'DEM votes 2014': 224,
#   'REP votes 2014': 501,
#   'DEM votes 2016': 299,
#   'REP votes 2016': 772,
#   'DEM vote share': 0.29120267260579064,
#   'midterm voter percentage': 0.676937441643324,
#   'DEM missing voters': 100.75612472160356,
#   'REP missing voters': 245.24387527839647,
#   'DEM potential gain': -144.48775055679292},
#  {'Precinct': 'VOL803',
#   'DEM votes 2014': 269,
#   'REP votes 2014': 728,
#   'DEM votes 2016': 374,
#   'REP votes 2016': 957,
#   'DEM vote share': 0.2762027491408935,
#   'midterm voter percentage': 0.749060856498873,
#   'DEM missing voters': 92.25171821305842,
#   'REP missing voters': 241.74828178694156,
#   'DEM potential gain': -149.49656357388312},
#  {'Precinct': 'VOL902',
#   'DEM votes 2014': 839,
#   'REP votes 2014': 1026,
#   'DEM votes 2016': 1020,
#   'REP votes 2016': 1665,
#   'DEM vote share': 0.4085714285714286,
#   'midterm voter percentage': 0.6945996275605214,
#   'DEM missing voters': 335.02857142857147,
#   'REP missing voters': 484.97142857142853,
#   'DEM potential gain': -149.94285714285706},
#  {'Precinct': 'VOL903',
#   'DEM votes 2014': 803,
#   'REP votes 2014': 986,
#   'DEM votes 2016': 1003,
#   'REP votes 2016': 1620,
#   'DEM vote share': 0.40933816863100636,
#   'midterm voter percentage': 0.6820434616850934,
#   'DEM missing voters': 341.3880326382593,
#   'REP missing voters': 492.6119673617407,
#   'DEM potential gain': -151.22393472348142},
#  {'Precinct': 'VOL904',
#   'DEM votes 2014': 797,
#   'REP votes 2014': 1052,
#   'DEM votes 2016': 993,
#   'REP votes 2016': 1627,
#   'DEM vote share': 0.4005370328932647,
#   'midterm voter percentage': 0.7057251908396946,
#   'DEM missing voters': 308.8140523607071,
#   'REP missing voters': 462.1859476392929,
#   'DEM potential gain': -153.37189527858584},
#  {'Precinct': 'STJ208',
#   'DEM votes 2014': 205,
#   'REP votes 2014': 586,
#   'DEM votes 2016': 296,
#   'REP votes 2016': 824,
#   'DEM vote share': 0.2621664050235479,
#   'midterm voter percentage': 0.70625,
#   'DEM missing voters': 86.25274725274726,
#   'REP missing voters': 242.74725274725273,
#   'DEM potential gain': -156.49450549450546},
#  {'Precinct': 'VOL202',
#   'DEM votes 2014': 709,
#   'REP votes 2014': 1048,
#   'DEM votes 2016': 1053,
#   'REP votes 2016': 1539,
#   'DEM vote share': 0.4051506093354794,
#   'midterm voter percentage': 0.6778549382716049,
#   'DEM missing voters': 338.3007587951253,
#   'REP missing voters': 496.6992412048747,
#   'DEM potential gain': -158.39848240974936},
#  {'Precinct': 'VOL508',
#   'DEM votes 2014': 420,
#   'REP votes 2014': 671,
#   'DEM votes 2016': 546,
#   'REP votes 2016': 1097,
#   'DEM vote share': 0.3533284564740307,
#   'midterm voter percentage': 0.6640292148508825,
#   'DEM missing voters': 195.03730797366495,
#   'REP missing voters': 356.96269202633505,
#   'DEM potential gain': -161.9253840526701},
#  {'Precinct': 'LAK62',
#   'DEM votes 2014': 281,
#   'REP votes 2014': 744,
#   'DEM votes 2016': 427,
#   'REP votes 2016': 991,
#   'DEM vote share': 0.2898076135898485,
#   'midterm voter percentage': 0.7228490832157969,
#   'DEM missing voters': 113.89439214081047,
#   'REP missing voters': 279.10560785918955,
#   'DEM potential gain': -165.2112157183791},
#  {'Precinct': 'LAK5',
#   'DEM votes 2014': 313,
#   'REP votes 2014': 667,
#   'DEM votes 2016': 462,
#   'REP votes 2016': 979,
#   'DEM vote share': 0.3201156546881454,
#   'midterm voter percentage': 0.6800832755031229,
#   'DEM missing voters': 147.57331681123503,
#   'REP missing voters': 313.42668318876497,
#   'DEM potential gain': -165.85336637752994},
#  {'Precinct': 'VOL107',
#   'DEM votes 2014': 176,
#   'REP votes 2014': 530,
#   'DEM votes 2016': 276,
#   'REP votes 2016': 778,
#   'DEM vote share': 0.25681818181818183,
#   'midterm voter percentage': 0.6698292220113852,
#   'DEM missing voters': 89.37272727272727,
#   'REP missing voters': 258.6272727272727,
#   'DEM potential gain': -169.25454545454545},
#  {'Precinct': 'VOL804',
#   'DEM votes 2014': 762,
#   'REP votes 2014': 1189,
#   'DEM votes 2016': 942,
#   'REP votes 2016': 1685,
#   'DEM vote share': 0.3722149410222805,
#   'midterm voter percentage': 0.7426722497145032,
#   'DEM missing voters': 251.6173001310616,
#   'REP missing voters': 424.3826998689384,
#   'DEM potential gain': -172.7653997378768},
#  {'Precinct': 'VOL404',
#   'DEM votes 2014': 156,
#   'REP votes 2014': 579,
#   'DEM votes 2016': 263,
#   'REP votes 2016': 797,
#   'DEM vote share': 0.23342618384401115,
#   'midterm voter percentage': 0.6933962264150944,
#   'DEM missing voters': 75.86350974930362,
#   'REP missing voters': 249.13649025069637,
#   'DEM potential gain': -173.27298050139274},
#  {'Precinct': 'FLA7',
#   'DEM votes 2014': 262,
#   'REP votes 2014': 694,
#   'DEM votes 2016': 337,
#   'REP votes 2016': 986,
#   'DEM vote share': 0.2628345765686705,
#   'midterm voter percentage': 0.7226001511715797,
#   'DEM missing voters': 96.46028960070207,
#   'REP missing voters': 270.5397103992979,
#   'DEM potential gain': -174.07942079859583},
#  {'Precinct': 'VOL522',
#   'DEM votes 2014': 731,
#   'REP votes 2014': 839,
#   'DEM votes 2016': 1071,
#   'REP votes 2016': 1627,
#   'DEM vote share': 0.42221180880974696,
#   'midterm voter percentage': 0.5819125277983692,
#   'DEM missing voters': 476.2549203373946,
#   'REP missing voters': 651.7450796626055,
#   'DEM potential gain': -175.49015932521087},
#  {'Precinct': 'VOL224',
#   'DEM votes 2014': 665,
#   'REP votes 2014': 1241,
#   'DEM votes 2016': 945,
#   'REP votes 2016': 1600,
#   'DEM vote share': 0.36171646820939113,
#   'midterm voter percentage': 0.7489194499017682,
#   'DEM missing voters': 231.13682318580092,
#   'REP missing voters': 407.86317681419905,
#   'DEM potential gain': -176.72635362839813},
#  {'Precinct': 'FLA10',
#   'DEM votes 2014': 641,
#   'REP votes 2014': 709,
#   'DEM votes 2016': 995,
#   'REP votes 2016': 1517,
#   'DEM vote share': 0.4236147074054894,
#   'midterm voter percentage': 0.5374203821656051,
#   'DEM missing voters': 492.2402900051787,
#   'REP missing voters': 669.7597099948213,
#   'DEM potential gain': -177.51941998964259},
#  {'Precinct': 'STJ308',
#   'DEM votes 2014': 435,
#   'REP votes 2014': 1019,
#   'DEM votes 2016': 629,
#   'REP votes 2016': 1303,
#   'DEM vote share': 0.3142350856467809,
#   'midterm voter percentage': 0.7525879917184265,
#   'DEM missing voters': 150.20437093916127,
#   'REP missing voters': 327.7956290608388,
#   'DEM potential gain': -177.59125812167753},
#  {'Precinct': 'VOL602',
#   'DEM votes 2014': 813,
#   'REP votes 2014': 1077,
#   'DEM votes 2016': 1354,
#   'REP votes 2016': 1800,
#   'DEM vote share': 0.4296193497224425,
#   'midterm voter percentage': 0.5992390615091947,
#   'DEM missing voters': 543.0388580491673,
# ...
#   'REP votes 2014': 884,
#   'DEM votes 2016': 860,
#   'REP votes 2016': 1129,
#   'DEM vote share': 0.37812789620018533,
#   'midterm voter percentage': 0.6274509803921569,
#   'DEM missing voters': 280.1927710843373,
#   'REP missing voters': 460.80722891566273,
#   'DEM potential gain': -180.6144578313254},
#  {'Precinct': 'VOL502',
#   'DEM votes 2014': 1154,
#   'REP votes 2014': 1579,
#   'DEM votes 2016': 1391,
#   'REP votes 2016': 2247,
#   'DEM vote share': 0.39946633181604146,
#   'midterm voter percentage': 0.7512369433754811,
#   'DEM missing voters': 361.5170302935175,
#   'REP missing voters': 543.4829697064825,
#   'DEM potential gain': -181.96593941296504},
#  {'Precinct': 'VOL907',
#   'DEM votes 2014': 658,
#   'REP votes 2014': 1134,
#   'DEM votes 2016': 752,
#   'REP votes 2016': 1616,
#   'DEM vote share': 0.3389423076923077,
#   'midterm voter percentage': 0.7567567567567568,
#   'DEM missing voters': 195.23076923076923,
#   'REP missing voters': 380.7692307692308,
#   'DEM potential gain': -185.53846153846155},
#  {'Precinct': 'VOL816',
#   'DEM votes 2014': 322,
#   'REP votes 2014': 647,
#   'DEM votes 2016': 370,
#   'REP votes 2016': 1046,
#   'DEM vote share': 0.290146750524109,
#   'midterm voter percentage': 0.684322033898305,
#   'DEM missing voters': 129.6955974842767,
#   'REP missing voters': 317.30440251572327,
#   'DEM potential gain': -187.60880503144656},
#  {'Precinct': 'VOL208',
#   'DEM votes 2014': 915,
#   'REP votes 2014': 1420,
#   'DEM votes 2016': 1298,
#   'REP votes 2016': 1976,
#   'DEM vote share': 0.39454448208236764,
#   'midterm voter percentage': 0.713194868662187,
#   'DEM missing voters': 370.4772686753432,
#   'REP missing voters': 568.5227313246569,
#   'DEM potential gain': -198.04546264931366},
#  {'Precinct': 'VOL532',
#   'DEM votes 2014': 475,
#   'REP votes 2014': 1150,
#   'DEM votes 2016': 584,
#   'REP votes 2016': 1503,
#   'DEM vote share': 0.28529094827586204,
#   'midterm voter percentage': 0.7786296118830858,
#   'DEM missing voters': 131.80441810344826,
#   'REP missing voters': 330.1955818965517,
#   'DEM potential gain': -198.39116379310343},
#  {'Precinct': 'VOL307',
#   'DEM votes 2014': 388,
#   'REP votes 2014': 990,
#   'DEM votes 2016': 797,
#   'REP votes 2016': 1233,
#   'DEM vote share': 0.3477112676056338,
#   'midterm voter percentage': 0.6788177339901478,
#   'DEM missing voters': 226.70774647887325,
#   'REP missing voters': 425.2922535211268,
#   'DEM potential gain': -198.58450704225353},
#  {'Precinct': 'VOL805',
#   'DEM votes 2014': 1009,
#   'REP votes 2014': 1635,
#   'DEM votes 2016': 1255,
#   'REP votes 2016': 2188,
#   'DEM vote share': 0.3719402004271398,
#   'midterm voter percentage': 0.7679349404589021,
#   'DEM missing voters': 297.18022014128474,
#   'REP missing voters': 501.81977985871526,
#   'DEM potential gain': -204.63955971743053},
#  {'Precinct': 'FLA21',
#   'DEM votes 2014': 931,
#   'REP votes 2014': 1232,
#   'DEM votes 2016': 1461,
#   'REP votes 2016': 2032,
#   'DEM vote share': 0.4229137199434229,
#   'midterm voter percentage': 0.6192384769539078,
#   'DEM missing voters': 562.4752475247525,
#   'REP missing voters': 767.5247524752474,
#   'DEM potential gain': -205.0495049504949},
#  {'Precinct': 'FLA31',
#   'DEM votes 2014': 518,
#   'REP votes 2014': 1221,
#   'DEM votes 2016': 652,
#   'REP votes 2016': 1586,
#   'DEM vote share': 0.29419160170983155,
#   'midterm voter percentage': 0.7770330652368186,
#   'DEM missing voters': 146.80160925320595,
#   'REP missing voters': 352.198390746794,
#   'DEM potential gain': -205.39678149358807},
#  {'Precinct': 'LAK4',
#   'DEM votes 2014': 304,
#   'REP votes 2014': 755,
#   'DEM votes 2016': 434,
#   'REP votes 2016': 1119,
#   'DEM vote share': 0.28254211332312407,
#   'midterm voter percentage': 0.68190598840953,
#   'DEM missing voters': 139.5758039816233,
#   'REP missing voters': 354.42419601837673,
#   'DEM potential gain': -214.84839203675344},
#  {'Precinct': 'VOL726',
#   'DEM votes 2014': 578,
#   'REP votes 2014': 1366,
#   'DEM votes 2016': 679,
#   'REP votes 2016': 1773,
#   'DEM vote share': 0.2859417652411283,
#   'midterm voter percentage': 0.7928221859706363,
#   'DEM missing voters': 145.25841674249318,
#   'REP missing voters': 362.7415832575069,
#   'DEM potential gain': -217.4831665150137},
#  {'Precinct': 'VOL501',
#   'DEM votes 2014': 474,
#   'REP votes 2014': 1048,
#   'DEM votes 2016': 615,
#   'REP votes 2016': 1461,
#   'DEM vote share': 0.3026681489716509,
#   'midterm voter percentage': 0.733140655105973,
#   'DEM missing voters': 167.6781545302946,
#   'REP missing voters': 386.32184546970535,
#   'DEM potential gain': -218.64369093941076},
#  {'Precinct': 'STJ306',
#   'DEM votes 2014': 403,
#   'REP votes 2014': 1005,
#   'DEM votes 2016': 558,
#   'REP votes 2016': 1368,
#   'DEM vote share': 0.2882423515296941,
#   'midterm voter percentage': 0.731048805815161,
#   'DEM missing voters': 149.30953809238153,
#   'REP missing voters': 368.69046190761844,
#   'DEM potential gain': -219.3809238152369},
#  {'Precinct': 'FLA3',
#   'DEM votes 2014': 338,
#   'REP votes 2014': 562,
#   'DEM votes 2016': 444,
#   'REP votes 2016': 1085,
#   'DEM vote share': 0.3219431864965006,
#   'midterm voter percentage': 0.5886200130804448,
#   'DEM missing voters': 202.50226430629888,
#   'REP missing voters': 426.49773569370115,
#   'DEM potential gain': -223.99547138740226},
#  {'Precinct': 'VOL512',
#   'DEM votes 2014': 865,
#   'REP votes 2014': 1401,
#   'DEM votes 2016': 1244,
#   'REP votes 2016': 1998,
#   'DEM vote share': 0.3828976034858388,
#   'midterm voter percentage': 0.6989512646514497,
#   'DEM missing voters': 373.7080610021787,
#   'REP missing voters': 602.2919389978214,
#   'DEM potential gain': -228.5838779956427},
#  {'Precinct': 'VOL412',
#   'DEM votes 2014': 221,
#   'REP votes 2014': 378,
#   'DEM votes 2016': 386,
#   'REP votes 2016': 873,
#   'DEM vote share': 0.32669537136706134,
#   'midterm voter percentage': 0.47577442414614773,
#   'DEM missing voters': 215.61894510226048,
#   'REP missing voters': 444.38105489773955,
#   'DEM potential gain': -228.76210979547906},
#  {'Precinct': 'LAK92',
#   'DEM votes 2014': 232,
#   'REP votes 2014': 731,
#   'DEM votes 2016': 397,
#   'REP votes 2016': 1074,
#   'DEM vote share': 0.25842235004108466,
#   'midterm voter percentage': 0.6546566961250849,
#   'DEM missing voters': 131.278553820871,
#   'REP missing voters': 376.721446179129,
#   'DEM potential gain': -245.44289235825798},
#  {'Precinct': 'VOL728',
#   'DEM votes 2014': 850,
#   'REP votes 2014': 1296,
#   'DEM votes 2016': 1100,
#   'REP votes 2016': 2017,
#   'DEM vote share': 0.37051111533346,
#   'midterm voter percentage': 0.6884825152390118,
#   'DEM missing voters': 359.76629298878964,
#   'REP missing voters': 611.2337070112104,
#   'DEM potential gain': -251.46741402242077},
#  {'Precinct': 'FLA37',
#   'DEM votes 2014': 378,
#   'REP votes 2014': 764,
#   'DEM votes 2016': 573,
#   'REP votes 2016': 1275,
#   'DEM vote share': 0.31806020066889634,
#   'midterm voter percentage': 0.6179653679653679,
#   'DEM missing voters': 224.5505016722408,
#   'REP missing voters': 481.44949832775916,
#   'DEM potential gain': -256.8989966555183},
#  {'Precinct': 'LAK7',
#   'DEM votes 2014': 388,
#   'REP votes 2014': 1099,
#   'DEM votes 2016': 627,
#   'REP votes 2016': 1495,
#   'DEM vote share': 0.28124134109171517,
#   'midterm voter percentage': 0.7007540056550424,
#   'DEM missing voters': 178.58825159323914,
#   'REP missing voters': 456.41174840676086,
#   'DEM potential gain': -277.82349681352173},
#  {'Precinct': 'FLA33',
#   'DEM votes 2014': 648,
#   'REP votes 2014': 1190,
#   'DEM votes 2016': 874,
#   'REP votes 2016': 1821,
#   'DEM vote share': 0.3357599823516435,
#   'midterm voter percentage': 0.6820037105751392,
#   'DEM missing voters': 287.7463048753585,
#   'REP missing voters': 569.2536951246415,
#   'DEM potential gain': -281.507390249283},
#  {'Precinct': 'VOL808',
#   'DEM votes 2014': 1072,
#   'REP votes 2014': 1380,
#   'DEM votes 2016': 1691,
#   'REP votes 2016': 2491,
#   'DEM vote share': 0.4164908049442267,
#   'midterm voter percentage': 0.5863223338115734,
#   'DEM missing voters': 720.5290925535122,
#   'REP missing voters': 1009.4709074464879,
#   'DEM potential gain': -288.9418148929757},
#  {'Precinct': 'VOL201',
#   'DEM votes 2014': 885,
#   'REP votes 2014': 1716,
#   'DEM votes 2016': 1249,
#   'REP votes 2016': 2310,
#   'DEM vote share': 0.3464285714285714,
#   'midterm voter percentage': 0.730823264962068,
#   'DEM missing voters': 331.87857142857143,
#   'REP missing voters': 626.1214285714286,
#   'DEM potential gain': -294.2428571428572},
#  {'Precinct': 'VOL301',
#   'DEM votes 2014': 483,
#   'REP votes 2014': 1138,
#   'DEM votes 2016': 1061,
#   'REP votes 2016': 1621,
#   'DEM vote share': 0.35881942830583313,
#   'midterm voter percentage': 0.6043997017151379,
#   'DEM missing voters': 380.707413432489,
#   'REP missing voters': 680.2925865675111,
#   'DEM potential gain': -299.5851731350221},
#  {'Precinct': 'FLA27',
#   'DEM votes 2014': 1047,
#   'REP votes 2014': 1683,
#   'DEM votes 2016': 1454,
#   'REP votes 2016': 2482,
#   'DEM vote share': 0.37518751875187517,
#   'midterm voter percentage': 0.6935975609756098,
#   'DEM missing voters': 452.47614761476143,
#   'REP missing voters': 753.5238523852386,
#   'DEM potential gain': -301.04770477047714},
#  {'Precinct': 'FLA9',
#   'DEM votes 2014': 1087,
#   'REP votes 2014': 1455,
#   'DEM votes 2016': 1544,
#   'REP votes 2016': 2502,
#   'DEM vote share': 0.39936247723132967,
#   'midterm voter percentage': 0.6282748393475037,
#   'DEM missing voters': 600.6411657559198,
#   'REP missing voters': 903.3588342440802,
#   'DEM potential gain': -302.71766848816037},
#  {'Precinct': 'VOL304',
#   'DEM votes 2014': 453,
#   'REP votes 2014': 1321,
#   'DEM votes 2016': 1043,
#   'REP votes 2016': 1653,
#   'DEM vote share': 0.334675615212528,
#   'midterm voter percentage': 0.6580118694362018,
#   'DEM missing voters': 308.5709172259508,
#   'REP missing voters': 613.4290827740492,
#   'DEM potential gain': -304.85816554809844},
#  {'Precinct': 'VOL716',
#   'DEM votes 2014': 342,
#   'REP votes 2014': 1303,
#   'DEM votes 2016': 484,
#   'REP votes 2016': 1699,
#   'DEM vote share': 0.21577847439916406,
#   'midterm voter percentage': 0.7535501603298214,
#   'DEM missing voters': 116.08881922675026,
#   'REP missing voters': 421.9111807732497,
#   'DEM potential gain': -305.82236154649945},
#  {'Precinct': 'STJ309',
#   'DEM votes 2014': 1081,
#   'REP votes 2014': 2158,
#   'DEM votes 2016': 1528,
#   'REP votes 2016': 2726,
#   'DEM vote share': 0.3481916455358334,
#   'midterm voter percentage': 0.7614010343206394,
#   'DEM missing voters': 353.4145202188709,
#   'REP missing voters': 661.5854797811292,
#   'DEM potential gain': -308.17095956225825},
#  {'Precinct': 'VOL215',
#   'DEM votes 2014': 702,
#   'REP votes 2014': 1299,
#   'DEM votes 2016': 1194,
#   'REP votes 2016': 1975,
#   'DEM vote share': 0.3667311411992263,
#   'midterm voter percentage': 0.6314294730198801,
#   'DEM missing voters': 428.3419729206963,
#   'REP missing voters': 739.6580270793038,
#   'DEM potential gain': -311.31605415860747},
#  {'Precinct': 'LAK32',
#   'DEM votes 2014': 619,
#   'REP votes 2014': 1643,
#   'DEM votes 2016': 1013,
#   'REP votes 2016': 2055,
#   'DEM vote share': 0.30619136960600374,
#   'midterm voter percentage': 0.7372881355932204,
#   'DEM missing voters': 246.79024390243902,
#   'REP missing voters': 559.209756097561,
#   'DEM potential gain': -312.419512195122},
#  {'Precinct': 'LAK93',
#   'DEM votes 2014': 486,
#   'REP votes 2014': 1069,
#   'DEM votes 2016': 792,
#   'REP votes 2016': 1640,
#   'DEM vote share': 0.32054176072234764,
#   'midterm voter percentage': 0.639391447368421,
#   'DEM missing voters': 281.11512415349887,
#   'REP missing voters': 595.8848758465011,
#   'DEM potential gain': -314.76975169300226},
#  {'Precinct': 'VOL732',
#   'DEM votes 2014': 799,
#   'REP votes 2014': 1407,
#   'DEM votes 2016': 1124,
#   'REP votes 2016': 2150,
#   'DEM vote share': 0.3509124087591241,
#   'midterm voter percentage': 0.6737935247403788,
#   'DEM missing voters': 374.7744525547445,
#   'REP missing voters': 693.2255474452554,
#   'DEM potential gain': -318.4510948905109},
#  {'Precinct': 'VOL706',
#   'DEM votes 2014': 766,
#   'REP votes 2014': 1538,
#   'DEM votes 2016': 1025,
#   'REP votes 2016': 2214,
#   'DEM vote share': 0.32311022911780624,
#   'midterm voter percentage': 0.7113306576103736,
#   'DEM missing voters': 302.10806422514884,
#   'REP missing voters': 632.8919357748512,
#   'DEM potential gain': -330.7838715497023},
#  {'Precinct': 'VOL510',
#   'DEM votes 2014': 767,
#   'REP votes 2014': 1621,
#   'DEM votes 2016': 1050,
#   'REP votes 2016': 2260,
#   'DEM vote share': 0.3188838188838189,
#   'midterm voter percentage': 0.7214501510574018,
#   'DEM missing voters': 294.010881010881,
#   'REP missing voters': 627.989118989119,
#   'DEM potential gain': -333.978237978238},
#  {'Precinct': 'VOL729',
#   'DEM votes 2014': 771,
#   'REP votes 2014': 1467,
#   'DEM votes 2016': 1172,
#   'REP votes 2016': 2168,
#   'DEM vote share': 0.3483327357475798,
#   'midterm voter percentage': 0.670059880239521,
#   'DEM missing voters': 383.8626747938329,
#   'REP missing voters': 718.137325206167,
#   'DEM potential gain': -334.2746504123341},
#  {'Precinct': 'VOL305',
#   'DEM votes 2014': 510,
#   'REP votes 2014': 1490,
#   'DEM votes 2016': 1071,
#   'REP votes 2016': 1876,
#   'DEM vote share': 0.31958762886597936,
#   'midterm voter percentage': 0.6786562606040041,
#   'DEM missing voters': 302.64948453608247,
#   'REP missing voters': 644.3505154639175,
#   'DEM potential gain': -341.70103092783506},
#  {'Precinct': 'STJ304',
#   'DEM votes 2014': 806,
#   'REP votes 2014': 1605,
#   'DEM votes 2016': 1046,
#   'REP votes 2016': 2332,
#   'DEM vote share': 0.31991708412506475,
#   'midterm voter percentage': 0.7137359384251036,
#   'DEM missing voters': 309.3598203489376,
#   'REP missing voters': 657.6401796510625,
#   'DEM potential gain': -348.28035930212485},
#  {'Precinct': 'VOL306',
#   'DEM votes 2014': 548,
#   'REP votes 2014': 1855,
#   'DEM votes 2016': 1125,
#   'REP votes 2016': 2199,
#   'DEM vote share': 0.2921250218264362,
#   'midterm voter percentage': 0.7229241877256317,
#   'DEM missing voters': 269.04714510214774,
#   'REP missing voters': 651.9528548978523,
#   'DEM potential gain': -382.9057097957045},
#  {'Precinct': 'FLA29',
#   'DEM votes 2014': 715,
#   'REP votes 2014': 1807,
#   'DEM votes 2016': 1020,
#   'REP votes 2016': 2433,
#   'DEM vote share': 0.2903765690376569,
#   'midterm voter percentage': 0.7303793802490588,
#   'DEM missing voters': 270.3405857740586,
#   'REP missing voters': 660.6594142259414,
#   'DEM potential gain': -390.31882845188284},
#  {'Precinct': 'FLA23',
#   'DEM votes 2014': 1600,
#   'REP votes 2014': 2550,
#   'DEM votes 2016': 2152,
#   'REP votes 2016': 3686,
#   'DEM vote share': 0.37565078093712456,
#   'midterm voter percentage': 0.710859883521754,
#   'DEM missing voters': 634.0985182218662,
#   'REP missing voters': 1053.9014817781338,
#   'DEM potential gain': -419.8029635562675},
#  {'Precinct': 'STJ307',
#   'DEM votes 2014': 712,
#   'REP votes 2014': 1699,
#   'DEM votes 2016': 1000,
#   'REP votes 2016': 2430,
#   'DEM vote share': 0.293100496490327,
#   'midterm voter percentage': 0.7029154518950438,
#   'DEM missing voters': 298.6694059236432,
#   'REP missing voters': 720.3305940763568,
#   'DEM potential gain': -421.6611881527136},
#  {'Precinct': 'LAK100',
#   'DEM votes 2014': 484,
#   'REP votes 2014': 1388,
#   'DEM votes 2016': 916,
#   'REP votes 2016': 1998,
#   'DEM vote share': 0.29251984956122024,
#   'midterm voter percentage': 0.6424159231297186,
#   'DEM missing voters': 304.8056832427915,
#   'REP missing voters': 737.1943167572085,
#   'DEM potential gain': -432.38863351441705},
#  {'Precinct': 'STJ305',
#   'DEM votes 2014': 1009,
#   'REP votes 2014': 1974,
#   'DEM votes 2016': 1501,
#   'REP votes 2016': 2886,
#   'DEM vote share': 0.3405698778833107,
#   'midterm voter percentage': 0.6799635286072487,
#   'DEM missing voters': 478.16010854816824,
#   'REP missing voters': 925.8398914518317,
#   'DEM potential gain': -447.67978290366347},
#  {'Precinct': 'STJ302',
#   'DEM votes 2014': 675,
#   'REP votes 2014': 1715,
#   'DEM votes 2016': 912,
#   'REP votes 2016': 2581,
#   'DEM vote share': 0.26976032636409997,
#   'midterm voter percentage': 0.6842255940452333,
#   'DEM missing voters': 297.54563997960224,
#   'REP missing voters': 805.4543600203978,
#   'DEM potential gain': -507.9087200407955}]

# %%
for dist_name in comp_dist_names:
    with open("dist_table{}.csv".format(dist_name.replace(" ", "_")), 'w') as csvfile:
        dictwriter = csv.DictWriter(csvfile, fieldnames)
        dictwriter.writeheader()
        for row in dict_writer_formatter(districts_dict[dist_name]):
            dictwriter.writerow(row)

# %%
for district, results in districts_dict.items():
    print(district)
    print(results[0])
    print()
# Out:
#  District 6
# ('VOL620', defaultdict(<class 'collections.Counter'>, {'2014 General Election': Counter({'REP': 6, 'district': ' District 6', 'DEM': 383, ' ': 10, 'total': 389, 'ratio': 0.9845758354755784}), '2016 General Election': Counter({'REP': 55, 'district': ' District 6', 'DEM': 1343, ' ': 57, 'total': 1398, 'ratio': 0.9606580829756796}), 'ratio': 0.965864577504197, 'voter_increase': 1009, 'midterm_voter_percentage': 0.2782546494992847, 'dem_missing_voters': 974.5573587017348, 'rep_missing_voters': 34.442641298265265, 'dem_delta': 940.1147174034695}))
#
#  District 15
# ('HIL964', defaultdict(<class 'collections.Counter'>, {'2014 General Election': Counter({'REP': 23, 'district': ' District 15', 'DEM': 103, ' ': 5, 'total': 126, 'ratio': 0.8174603174603174}), '2016 General Election': Counter({'REP': 49, 'district': ' District 15', 'DEM': 235, ' ': 15, 'total': 284, 'ratio': 0.8274647887323944}), 'ratio': 0.824390243902439, 'voter_increase': 158, 'midterm_voter_percentage': 0.44366197183098594, 'dem_missing_voters': 130.25365853658536, 'rep_missing_voters': 27.74634146341464, 'dem_delta': 102.50731707317073}))
#
#  District 16
# ('MAN205', defaultdict(<class 'collections.Counter'>, {'2014 General Election': Counter({'REP': 34, 'district': ' District 16', 'DEM': 492, ' ': 13, 'total': 526, 'ratio': 0.935361216730038}), '2016 General Election': Counter({'REP': 85, 'district': ' District 16', 'DEM': 759, ' ': 24, 'total': 844, 'ratio': 0.8992890995260664}), 'ratio': 0.9131386861313868, 'voter_increase': 318, 'midterm_voter_percentage': 0.6232227488151659, 'dem_missing_voters': 290.37810218978103, 'rep_missing_voters': 27.62189781021899, 'dem_delta': 262.75620437956206}))
#
#  District 18
# ('STL18', defaultdict(<class 'collections.Counter'>, {'2014 General Election': Counter({'REP': 20, 'district': ' District 18', 'DEM': 613, ' ': 12, 'total': 633, 'ratio': 0.9684044233807267}), '2016 General Election': Counter({'REP': 51, 'district': ' District 18', 'DEM': 991, 'NPA': 26, ' ': 24, 'total': 1042, 'ratio': 0.9510556621880998}), 'ratio': 0.9576119402985075, 'voter_increase': 409, 'midterm_voter_percentage': 0.6074856046065259, 'dem_missing_voters': 391.66328358208955, 'rep_missing_voters': 17.336716417910438, 'dem_delta': 374.3265671641791}))
#
#  District 25
# ('HEN1', defaultdict(<class 'collections.Counter'>, {'2014 General Election': Counter({'REP': 220, 'district': ' District 20', 'DEM': 973, ' ': 32, 'total': 1193, 'ratio': 0.815590947191953}), '2016 General Election': Counter({'REP': 496, 'district': ' District 25', 'DEM': 1526, ' ': 113, 'total': 2022, 'ratio': 0.7546983184965381}), 'ratio': 0.7772939346811819, 'voter_increase': 829, 'midterm_voter_percentage': 0.5900098911968348, 'dem_missing_voters': 644.3766718506998, 'rep_missing_voters': 184.6233281493002, 'dem_delta': 459.7533437013997}))
#
#  District 26
# ('DAD936', defaultdict(<class 'collections.Counter'>, {'2014 General Election': Counter({'REP': 6, 'district': ' District 26', 'DEM': 21, ' ': 3, 'total': 27, 'ratio': 0.7777777777777778}), '2016 General Election': Counter({'REP': 75, 'district': ' District 26', 'DEM': 203, 'NPA': 18, ' ': 13, 'total': 278, 'ratio': 0.7302158273381295}), 'ratio': 0.7344262295081967, 'voter_increase': 251, 'midterm_voter_percentage': 0.09712230215827339, 'dem_missing_voters': 184.34098360655736, 'rep_missing_voters': 66.65901639344263, 'dem_delta': 117.68196721311473}))
#
#  District 27
# ('DAD43', defaultdict(<class 'collections.Counter'>, {'2014 General Election': Counter({'REP': 39, 'district': ' District 23', 'DEM': 129, ' ': 13, 'total': 168, 'ratio': 0.7678571428571429}), '2016 General Election': Counter({'REP': 221, 'district': ' District 27', 'DEM': 408, ' ': 60, 'total': 629, 'ratio': 0.6486486486486487}), 'ratio': 0.6737766624843162, 'voter_increase': 461, 'midterm_voter_percentage': 0.2670906200317965, 'dem_missing_voters': 310.61104140526976, 'rep_missing_voters': 150.3889585947302, 'dem_delta': 160.22208281053955}))
